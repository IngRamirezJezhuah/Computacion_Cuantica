# %%
#probando  hacer modulos de menu para jupyterNotes
# Seaborn
import seaborn as sb


def Menu():
    variable_externa= input(str("Escribe algo"))
    menu = "=========================="
    space = " "
    for x in range(1):
        print(menu)
        print(space)
        print(variable_externa)
        print(space)
        print(menu)

# %% [markdown]
# # Libreria para hacer graficas
#
# La libreria se llama `Seaborn`
#
# Si necesito sacar mas cosas ir a la documentacion que esta en
#
# `https://seaborn.pydata.org/tutorial/introduction.html`

# %%
#aplica los estilos por defecto
sb.set_theme()

# Cargar  un ejemplpo de un data set
tips = sb.load_dataset("tips")

#crear una visualizacion
sb.relplot(
    data=tips,
    x="total_bill", y="tip", col= "time",
    hue="smoker", style="smoker", size="size",
)

# %% [markdown]
# # Control de las figuras

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n +1):
        plt.plot(x, np.sin(x +i * .5) * (n +2 - i) * flip)

sinplot()

# %% [markdown]
# # Ideas de implementacion de un Menu en python notes
#
# > para las cosas que quiero imprimir como un resultado que quiera poner dentro

# %%
Menu()
# Out:
# ...
#
# aadad
#
# ...
